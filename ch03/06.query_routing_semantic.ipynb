# %%
from langchain_community.utils.math import cosine_similarity 
from langchain_core.output_parsers import StrOutputParser 
from langchain_core.prompts import PromptTemplate 
from langchain_core.runnables import chain 
from langchain_ollama import ChatOllama, OllamaEmbeddings 

physics_template = '''
당신은 매우 똑똑한 물리학 교수입니다. 당신은 물리학에 대한 질문에 간결하고 쉽게 이해할 수 있는 방식으로 대답하는데 뛰어납니다. 
당신이 질문에 대한 답을 모를 때는 모른다고 인정합니다. 
다음 질문에 답하세요 :  {query}
'''

math_template = '''
당신은 매우 똑똑한 수학자입니다. 당신은 수학 문제에 대해 답하는데 뛰어납니다. 
당신은 어려운 문제를 구성요로소 분해하고 구성 요소를 해결한 다음 함께 모아 넓은 질문에 대답합니다.
다음 질문에 답하세요 :  {query}
'''

# %%
embeddings_model = OllamaEmbeddings(model='nomic-embed-text:latest')

prompt_templates = [physics_template, math_template] 

prompt_embeddings = embeddings_model.embed_documents(prompt_templates)

# %%
@chain 
def prompt_router(query):
    query_embedding = embeddings_model.embed_query(query)

    similarity = cosine_similarity([query_embedding], prompt_embeddings)[0]
    
    most_similar = prompt_templates[similarity.argmax()]
    
    print('수학 프롬프트 사용' if most_similar == math_template else '물리 프롬프트 사용')
    
    return PromptTemplate.from_template(most_similar)

# %%
sematic_router = (prompt_router | ChatOllama(model='gemma4:latest') | StrOutputParser())

result = sematic_router.invoke('블랙홀이란 무엇인가요?')

print('의미론적 라우팅 결과', result)
# Out:
# 수학 프롬프트 사용
# 의미론적 라우팅 결과 (잠시 침묵하며, 논문 초안을 정리하는 듯한 신중하고 지적인 분위기를 풍깁니다. 제 말은 항상 논리적 구조를 가지며, 추상적인 개념이라도 수학적 정밀성을 잃지 않습니다.)
#
# 질문 주신 ‘블랙홀’이라는 개념은 물리학, 특히 일반 상대성 이론(General Theory of Relativity)이라는 매우 광대하고 정교한 수학적 틀 위에서 이해해야 하는 문제입니다. 이는 단순한 ‘구멍’이나 ‘검은 물체’로 정의될 수 없습니다.
#
# 저는 이 복잡한 개념을 세 단계의 분석 과정으로 나누어 접근하겠습니다. 마치 복잡한 미분 방정식을 변수로 나누어 풀어나가듯, 핵심 구성 요소를 분해하고(Decomposition), 각 요소를 수학적/물리적으로 해결한 후(Solving), 최종적으로 종합적인 이해에 도달할 것입니다(Synthesis).
#
# ---
#
# ## 📐 I. 구성 요소 분해 (Decomposition of the Concept)
#
# 블랙홀을 정확하게 이해하기 위해서는 다음 네 가지 근본적인 구성 요소에 대한 분석이 필요합니다.
#
# **구성 요소 A: 시공간의 구조 (Spacetime Manifold)**
# 블랙홀을 배경으로 하는 우주적 환경 그 자체입니다. 우리가 '공간'이라고 인지하는 것이 사실은 시간과 결합된 4차원적 연속체라는 전제입니다. (아인슈타인의 개념)
#
# **구성 요소 B: 중력과 곡률 (Gravity and Curvature)**
# 질량(Mass)이 어떻게 시공간을 휘게 하는가 하는 문제입니다. 중력은 힘(Force)이라기보다는 시공간의 기하학적 변형(Geometric Deformation)으로 정의됩니다.
#
# **구성 요소 C: 붕괴의 한계점 (The Collapse Threshold)**
# 어떤 질량체가 자체 중력을 견디지 못하고 내부 압력에 의해 더 이상 지탱될 수 없는 임계점입니다. (항성 진화 과정의 수학적 한계)
#
# ...
